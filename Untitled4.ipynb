# %% [markdown]
# <a href="https://colab.research.google.com/github/tswhy1/Aiffel_quest_cr/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
upload = files.upload('Avengers.txt')
# Out:
#      <input type="file" id="files-18b94602-977b-4964-af72-4401ea76cb19" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-18b94602-977b-4964-af72-4401ea76cb19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Out:
# 단어 리스트: ['the', 'tesseract', 'has', 'awakened', 'it', 'is', 'on', 'a', 'neutral', 'world', 'a', 'human', 'world', 'they', 'wield', 'its', 'power', 'but', 'our', 'ally', 'knows', 'its', 'working', 'so', 'that', 'they', 'never', 'will', 'learn', 'hes', 'ready', 'to', 'lead', 'and', 'our', 'force', 'our', 'chitauri', 'will', 'follow', 'the', 'world', 'will', 'be', 'his', 'and', 'the', 'universe', 'yours', 'and', 'the', 'humans', 'what', 'can', 'they', 'do', 'but', 'burn', 'how', 'bad', 'is', 'it', 'thats', 'the', 'problem', 'sir', 'we', 'dont', 'know', 'dr', 'selvig', 'read', 'an', 'energy', 'surge', 'from', 'the', 'tesseract', 'four', 'hour', 'ago', 'nasa', 'didnt', 'authorize', 'selvig', 'to', 'pull', 'the', 'test', 'phase', 'he', 'wasnt', 'testing', 'it', 'he', 'wasnt', 'even', 'in', 'the', 'room', 'spontaneous', 'advancement', 'it', 'just', 'turned', 'itself', 'on', 'what', 'are', 'the', 'engine', 'levels', 'now', 'climbing', 'when', 'selvig', 'couldnt', 'shut', 'it', 'down', 'we', 
# ...

# %%
import re
from collections import Counter


def process_text(text):

    # 모든 문자를 소문자로 변환
    text = text.lower()

    # 모든 기호 제거 (정규 표현식 사용)
    text = re.sub(r'[^\w\s]', '', text)  # 알파벳과 숫자, 공백을 제외한 모든 기호 제거

    # 단어 단위로 분리
    words = text.split()  # 공백을 기준으로 단어 분리

    # 결과 출력
    print("단어 리스트:", words)  # 소문자 변환 후 기호 제거된 단어 리스트

    # 단어 빈도수 계산
    indexed_freq = word_freq(words)

    # 빈도수 딕셔너리 출력
    print("단어 빈도수 (정렬된 결과):")

    for index, (word, count) in indexed_freq.items():
        print(f"{index}: {word} - {count}")

    return


def get_freq_count(item):
    # 빈도수를 반환하는 함수
    return item[1]

def word_freq(words):
    # 각 단어별 빈도수를 딕셔너리 형태로 저장
    freq_dict = Counter(words)

    # 빈도수 순으로 내림차순 정렬 (lambda를 일반 함수로 대체)
    sorted_freq = sorted(freq_dict.items(), key=get_freq_count, reverse=True)

    # 정렬된 순서에 정수 인덱스 부여
    indexed_freq = {index: (word, count) for index, (word, count) in enumerate(sorted_freq)}

    return indexed_freq

def get_word_index(word, indexed_freq):
    # 특정 단어의 빈도수 인덱스를 반환
    for index, (w, count) in indexed_freq.items():
        if w == word:
            return index
    return -1  # 단어가 존재하지 않을 경우 -1 반환

if __name__ == "__main__":
    # Avengers.txt 파일을 불러와 결과 출력
    with open("/content/sample_data/Avengers.txt", "r") as file:
        text = file.read()

    process_text(text)

    # 사용자로부터 단어 입력받기
    text = input("단어를 입력하세요: \n")

    process_text(text)
# Out:
# 단어 리스트: ['the', 'tesseract', 'has', 'awakened', 'it', 'is', 'on', 'a', 'neutral', 'world', 'a', 'human', 'world', 'they', 'wield', 'its', 'power', 'but', 'our', 'ally', 'knows', 'its', 'working', 'so', 'that', 'they', 'never', 'will', 'learn', 'hes', 'ready', 'to', 'lead', 'and', 'our', 'force', 'our', 'chitauri', 'will', 'follow', 'the', 'world', 'will', 'be', 'his', 'and', 'the', 'universe', 'yours', 'and', 'the', 'humans', 'what', 'can', 'they', 'do', 'but', 'burn', 'how', 'bad', 'is', 'it', 'thats', 'the', 'problem', 'sir', 'we', 'dont', 'know', 'dr', 'selvig', 'read', 'an', 'energy', 'surge', 'from', 'the', 'tesseract', 'four', 'hour', 'ago', 'nasa', 'didnt', 'authorize', 'selvig', 'to', 'pull', 'the', 'test', 'phase', 'he', 'wasnt', 'testing', 'it', 'he', 'wasnt', 'even', 'in', 'the', 'room', 'spontaneous', 'advancement', 'it', 'just', 'turned', 'itself', 'on', 'what', 'are', 'the', 'engine', 'levels', 'now', 'climbing', 'when', 'selvig', 'couldnt', 'shut', 'it', 'down', 'we', 
# ...

# %%
import re
from collections import Counter


def process_text(text):

    # 모든 문자를 소문자로 변환
    text = text.lower()

    # 모든 기호 제거 (정규 표현식 사용)
    text = re.sub(r'[^\w\s]', '', text)  # 알파벳과 숫자, 공백을 제외한 모든 기호 제거

    # 단어 단위로 분리
    words = text.split()  # 공백을 기준으로 단어 분리

    # 결과 출력
    print("단어 리스트:", words)  # 소문자 변환 후 기호 제거된 단어 리스트

    # 단어 빈도수 계산
    indexed_freq = word_freq(words)

    # 빈도수 딕셔너리 출력
    print("단어 빈도수 (정렬된 결과):")

    for index, (word, count) in indexed_freq.items():
        print(f"{index}: {word} - {count}")

    return


def get_freq_count(item):
    # 빈도수를 반환하는 함수
    return item[1]

def word_freq(words):
    # 각 단어별 빈도수를 딕셔너리 형태로 저장
    freq_dict = Counter(words)

    # 빈도수 순으로 내림차순 정렬 (lambda를 일반 함수로 대체)
    sorted_freq = sorted(freq_dict.items(), key=get_freq_count, reverse=True)

    # 정렬된 순서에 정수 인덱스 부여
    indexed_freq = {index: (word, count) for index, (word, count) in enumerate(sorted_freq)}

    return indexed_freq

def get_word_index(word, indexed_freq):
    # 특정 단어의 빈도수 인덱스를 반환
    for index, (w, count) in indexed_freq.items():
        if w == word:
            return index
    return -1  # 단어가 존재하지 않을 경우 -1 반환

if __name__ == "__main__":
    # Avengers.txt 파일을 불러와 처리하고 결과 출력
    with open("/content/sample_data/Avengers.txt", "r") as file:
        text = file.read()

    process_text(text)

    # 사용자로부터 단어 입력받기
    text = input("단어를 입력하세요: \n")

    process_text(text)
# Out:
# 단어 리스트: ['the', 'tesseract', 'has', 'awakened', 'it', 'is', 'on', 'a', 'neutral', 'world', 'a', 'human', 'world', 'they', 'wield', 'its', 'power', 'but', 'our', 'ally', 'knows', 'its', 'working', 'so', 'that', 'they', 'never', 'will', 'learn', 'hes', 'ready', 'to', 'lead', 'and', 'our', 'force', 'our', 'chitauri', 'will', 'follow', 'the', 'world', 'will', 'be', 'his', 'and', 'the', 'universe', 'yours', 'and', 'the', 'humans', 'what', 'can', 'they', 'do', 'but', 'burn', 'how', 'bad', 'is', 'it', 'thats', 'the', 'problem', 'sir', 'we', 'dont', 'know', 'dr', 'selvig', 'read', 'an', 'energy', 'surge', 'from', 'the', 'tesseract', 'four', 'hour', 'ago', 'nasa', 'didnt', 'authorize', 'selvig', 'to', 'pull', 'the', 'test', 'phase', 'he', 'wasnt', 'testing', 'it', 'he', 'wasnt', 'even', 'in', 'the', 'room', 'spontaneous', 'advancement', 'it', 'just', 'turned', 'itself', 'on', 'what', 'are', 'the', 'engine', 'levels', 'now', 'climbing', 'when', 'selvig', 'couldnt', 'shut', 'it', 'down', 'we', 
# ...

# %%
def process_text(filename):
    # 파일을 읽어와 모든 문자를 소문자로 변환하고 기호 제거 및 단어 단위로 분리
    with open(filename, "r") as file:
        text = file.read()

    # 모든 문자를 소문자로 변환
    text = text.lower()

    # 모든 기호 제거 (정규 표현식 사용)
    text = re.sub(r'[\W\s]', '', text)

    # 단어 단위로 분리
    words = text.split()

    return words

if __name__ == "__main__":
    # Avengers.txt 파일을 불러와 처리하고 결과 출력
    processed_words = process_text("Avengers.txt")
    print(processed_words)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-23-f091de4f735f> in <cell line: 17>()
#      17 if __name__ == "__main__":
#      18     # Avengers.txt 파일을 불러와 처리하고 결과 출력
# ---> 19     processed_words = process_text("Avengers.txt")
#      20     print(processed_words)
#
# <ipython-input-23-f091de4f735f> in process_text(filename)
#       1 def process_text(filename):
#       2     # 파일을 읽어와 모든 문자를 소문자로 변환하고 기호 제거 및 단어 단위로 분리
# ----> 3     with open(filename, "r") as file:
#       4         text = file.read()
#       5
#
# IsADirectoryError: [Errno 21] Is a directory: 'Avengers.txt'

# %%
import re
def process_text(filename):
  with open(filename, "r", encoding='utf-8') as file:
    text = file.read()
    text = text.lower()
    text = re.sub(r'^ws')', '', text)
    words = text.split()
    return words
# Out:
#   File "<ipython-input-20-58d02ece6e70>", line 6
#     text = re.sub(r'^\w\s')', '', text)
#                                ^
# SyntaxError: unterminated string literal (detected at line 6)

# %%
import re
from collections import Counter


def process_text(text):

    # 모든 문자를 소문자로 변환
    text = text.lower()

    # 모든 기호 제거 (정규 표현식 사용)
    text = re.sub(r'[^\w\s]', '', text)  # 알파벳과 숫자, 공백을 제외한 모든 기호 제거

    # 단어 단위로 분리
    words = text.split()  # 공백을 기준으로 단어 분리

    # 결과 출력
    print("단어 리스트:", words)  # 소문자 변환 후 기호 제거된 단어 리스트

    # 단어 빈도수 계산
    indexed_freq = word_freq(words)

    # 빈도수 딕셔너리 출력
    print("단어 빈도수 (정렬된 결과):")

    for index, (word, count) in indexed_freq.items():
        print(f"{index}: {word} - {count}")

    return


def get_freq_count(item):
    # 빈도수를 반환하는 함수
    return item[1]

def word_freq(words):
    # 각 단어별 빈도수를 딕셔너리 형태로 저장
    freq_dict = Counter(words)

    # 빈도수 순으로 내림차순 정렬 (lambda를 일반 함수로 대체)
    sorted_freq = sorted(freq_dict.items(), key=get_freq_count, reverse=True)

    # 정렬된 순서에 정수 인덱스 부여
    indexed_freq = {index: (word, count) for index, (word, count) in enumerate(sorted_freq)}

    return indexed_freq

def get_word_index(word, indexed_freq):
    # 특정 단어의 빈도수 인덱스를 반환
    for index, (w, count) in indexed_freq.items():
        if w == word:
            return index
    return -1  # 단어가 존재하지 않을 경우 -1 반환

if __name__ == "__main__":
    # Avengers.txt 파일을 불러와 처리하고 결과 출력
    with open("/content/sample_data/Avengers.txt", "r") as file:
        text = file.read()

    process_text(text)

    # 사용자로부터 단어 입력받기
    text = input("단어를 입력하세요: \n")

    process_text(text)
# Out:
# 단어 리스트: ['the', 'tesseract', 'has', 'awakened', 'it', 'is', 'on', 'a', 'neutral', 'world', 'a', 'human', 'world', 'they', 'wield', 'its', 'power', 'but', 'our', 'ally', 'knows', 'its', 'working', 'so', 'that', 'they', 'never', 'will', 'learn', 'hes', 'ready', 'to', 'lead', 'and', 'our', 'force', 'our', 'chitauri', 'will', 'follow', 'the', 'world', 'will', 'be', 'his', 'and', 'the', 'universe', 'yours', 'and', 'the', 'humans', 'what', 'can', 'they', 'do', 'but', 'burn', 'how', 'bad', 'is', 'it', 'thats', 'the', 'problem', 'sir', 'we', 'dont', 'know', 'dr', 'selvig', 'read', 'an', 'energy', 'surge', 'from', 'the', 'tesseract', 'four', 'hour', 'ago', 'nasa', 'didnt', 'authorize', 'selvig', 'to', 'pull', 'the', 'test', 'phase', 'he', 'wasnt', 'testing', 'it', 'he', 'wasnt', 'even', 'in', 'the', 'room', 'spontaneous', 'advancement', 'it', 'just', 'turned', 'itself', 'on', 'what', 'are', 'the', 'engine', 'levels', 'now', 'climbing', 'when', 'selvig', 'couldnt', 'shut', 'it', 'down', 'we', 
# ...
