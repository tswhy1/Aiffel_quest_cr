# %% [markdown]
# <a href="https://colab.research.google.com/github/tswhy1/Aiffel_quest_cr/blob/main/Python/Py4/untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
#1 입력값 ≠ 정수 → ValueError 처리
def integer_input(prompt):
    while True: #정수를 입력할 때까지 반복
        try:
            input_num = int(input(prompt))
            return input_num
        except ValueError: #2 잘못된 입력 → 예외처리
            print("잘못된 입력입니다. 정수를 입력해주세요.")

# 연산식 정의
def calculator():

    num1 = integer_input("첫번째 정수를 입력하세요: ")

    while True:
        operator = input("연산자를 입력하세요(+, -, *, /, **): ")
        if operator in ['+','-','*','/','**']: # 4-1.지원하지 않는 연산자 예외처리
            break
        else:
            print("지원하지 않는 연산자입니다.") # 4-2.예외처리 메세지


    num2 = integer_input("두번째 정수를 입력하세요: ")


    try:
        if operator == '+':
            return num1 + num2
        elif operator == '-':
            return num1 - num2
        elif operator == '*':
            return num1 * num2
        elif operator == '/':
            return num1 / num2
        elif operator == '**':
            return math.pow(num1, num2)  # 5.math.pow 모듈 함수 사용


        result = calculator()
        print(f"계산결과: {num1} {operator} {num2} = {result}")


    except ZeroDivisionError:
        print("0으로 나눌 수 없습니다.") # 3. 나눗셈에서 0으로 나눌 수 없는 경우 예외처리



# 계산 실행

while True:
    calculator()
    continue_input = input("계속하시겠습니까? (y/n): ")
    if continue_input not in ['y','n']:
        print("잘못된 입력입니다. y 또는 n을 입력해주세요.")
    elif continue_input == 'n':
        print("계산기를 종료합니다.")
        break

def repeat_calcultor():
    while True:
        calculator()
        continue_input = input("계속하시겠습니까? (y/n): ")
        if continue_input not in ['y','n']:
            print("잘못된 입력입니다. y 또는 n을 입력해주세요.")
        elif continue_input == 'n':
            print("계산기를 종료합니다.")
            break

repeat_calcultor()

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 새 섹션
